# %% [markdown]
# # Writing Web Scrapping Code to Collect Images From Google
#
# The output would look like this one
#
# ![like.png](attachment:like.png)

# %% [markdown]
# ## loading the Libraries Necessaries

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
import os 
import requests
import urllib

# %% [markdown]
# ## Which Person Image do you Want to download And How much Images Do you Need

# %%
class_name = "My favourite"
search_term = "Elon Musk"
Images_needed = 30

# %% [markdown]
# ## Setting according to your prefrences (with and without browser opening while collecting image)

# %%
# #To run without browser opening
# op = webdriver.ChromeOptions()
# op.add_argument('headless')
# driver = webdriver.Chrome(options=op)
# driver.get("https://google.com")

# %%
#to open browser while running (we can visualize)
driver = webdriver.Chrome()
driver.get("https://google.com")

# %% [markdown]
# ## Setting the SearchBar in google And Entering the className

# %%
box = driver.find_element("xpath","/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input")
box.send_keys(search_term)
box.send_keys(Keys.ENTER)

# %% [markdown]
# ## moving to the images tab in google

# %%
driver.find_element("xpath","//*[@id='hdtb-msb']/div[1]/div/div[2]/a").click()

# %% [markdown]
# ## Getting the right amount of images needed from all the images in google images tab

# %%
starting_length = driver.execute_script("return document.body.scrollHeight")
finished_length = starting_length+1
Find_Images = True
while (starting_length != finished_length) & (Find_Images):
    starting_length = driver.execute_script("return document.body.scrollHeight")
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    soup = BeautifulSoup(driver.page_source,"lxml")
    all_images = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
    try:
        all_images = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
        if len(all_images) <= Images_needed:
            time.sleep(5)
            finished_length = driver.execute_script("return document.body.scrollHeight")
        else:
            all_images = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
            Find_Images = False
    except Exception as e:
        print(f"the exception occured as: {e}")
print("finished_scrolling")
# Out:
# finished_scrolling

# %% [markdown]
# ### Trying the challenge

# %%
all_details = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
if len(all_details) == 0 :
    driver.find_element("xpath",'//*[@id="hdtb-msb"]/div[1]/div/div[3]/a').click()
    starting_length = driver.execute_script("return document.body.scrollHeight")
    finished_length = starting_length+1
    Find_Images = True
    while (starting_length != finished_length) & (Find_Images):
        starting_length = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        soup = BeautifulSoup(driver.page_source,"lxml")
        all_images = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
        try:
            all_images = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
            if len(all_images) <= Images_needed:
                time.sleep(5)
                finished_length = driver.execute_script("return document.body.scrollHeight")
            else:
                all_images = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
                Find_Images = False
        except Exception as e:
            print(f"the exception occured as: {e}")
    print("finished_scrolling")    
    all_details=soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
# Out:
# finished_scrolling

# %% [markdown]
# ## Checking how many images we have

# %%
# soup = BeautifulSoup(driver.page_source,"html.parser")
soup = BeautifulSoup(driver.page_source,"html5lib")

# %%
all_images = soup.find_all("div",class_="isv-r PNCib MSM1fd BUooTd")
len(all_images)
# Out:
# 48

# %%
import pandas as pd
index = int(len(all_images))
index
# Out:
# 48

# %%
dataframe = pd.DataFrame(columns=["Blog_Link","Title","Source_Name"])
dataframe
# Out:
# Empty DataFrame
# Columns: [Blog_Link, Title, Source_Name]
# Index: []

# %%
for detail in all_details[:index]:
    link_and_title = detail.find("a",class_="VFACy kGQAp sMi44c d0NI4c lNHeqe WGvvNb")
    link = link_and_title.get("href")
    title = link_and_title.get("title")
    source = link_and_title.find("div",class_="dmeZbb").text
    dataframe = pd.concat([dataframe,pd.DataFrame({dataframe.columns[0]:[link],dataframe.columns[1]:[title],
                                                    dataframe.columns[2]:[source]})],ignore_index=True)
dataframe.head()
# Out:
#                       Blog_Link                       \
# 0  https://www.rollingstone.com/culture/culture-n...
# 1            https://en.wikipedia.org/wiki/Elon_Musk
# 2  https://www.cnbc.com/2023/02/08/biden-billiona...
# 3  https://www.hollywoodreporter.com/business/bus...
# 4     https://www.britannica.com/biography/Elon-Musk
#
#                         Title                              Source_Name
# 0  Elon Musk Reportedly Fires Twitter Engineer Ov...            Rolling Stone
# 1                              Elon Musk - Wikipedia                Wikipedia
# 2  Biden billionaire minimum tax: What Elon Musk ...                     CNBC
# 3  Elon Musk, Tesla Beat Investor Suit Over 'Fund...   The Hollywood Reporter
# 4  Elon Musk | Biography, SpaceX, Tesla, Twitter,...  Encyclopedia Britannica

# %% [markdown]
# ## Creating a folder with a Class_name

# %%
path = os.path.join(os.getcwd(),f"{class_name}")
os.makedirs(path,exist_ok=True)

# %%
# os.listdir(path)

# %% [markdown]
# ## Final Total Number Of Images

# %%
# #to get a image file without compression
# import urllib.request
# image_url = "give any image url from google we can get a image file without compression :)"
# request = urllib.request.Request(image_url, headers={"Accept-Encoding": "identity"})
# response = urllib.request.urlopen(request)
# with open("image.jpg", "wb") as f:
#     f.write(response.read())

# %%
dataframe
# Out:
#                        Blog_Link                       \
# 0   https://www.rollingstone.com/culture/culture-n...
# 1             https://en.wikipedia.org/wiki/Elon_Musk
# 2   https://www.cnbc.com/2023/02/08/biden-billiona...
# 3   https://www.hollywoodreporter.com/business/bus...
# 4      https://www.britannica.com/biography/Elon-Musk
# 5   https://www.biography.com/business-leaders/elo...
# 6   https://hls.harvard.edu/today/the-business-eth...
# 7      https://www.britannica.com/biography/Elon-Musk
# 8   https://fortune.com/2023/02/10/twitter-culture...
# 9   https://www.curbed.com/2023/02/elon-musk-neigh...
# 10         https://www.bbc.com/news/business-61234231
# 11  https://commons.wikimedia.org/wiki/Category:El...
# 12  https://www.marketwatch.com/story/teslas-elon-...
# 13  https://www.eonline.com/news/1322666/grimes-re...
# 14  https://www.npr.org/2022/06/01/1102513281/elon...
# 15  https://www.cnbc.com/2023/02/11/elon-musks-neu...
# 16  https://www.politico.eu/article/elon-musk-twit...
# 17  https://www.cnn.com/2023/01/26/politics/elon-m...
# 18  https://www.foxbusiness.com/markets/elon-musk-...
# 19  https://www.inc.com/magazine/20071201/entrepre...
# 20  https://www.businessinsider.com/elon-musk-rela...
# 21  https://www.newscientist.com/article/2342446-t...
# 22  https://www.reuters.com/technology/elon-musk-g...
# 23  https://www.wired.com/story/elon-musk-twitter-...
# 24  https://abcnews.go.com/Business/timeline-elon-...
# 25        https://www.youtube.com/watch?v=cdZZpaB2kDM
# 26  https://www.foxnews.com/category/person/elon-musk
# 27  https://people.com/parents/elon-musks-son-x-ow...
# 28  https://www.investopedia.com/articles/personal...
# 29  https://variety.com/2022/digital/news/elon-mus...
# 30  https://www.nytimes.com/2022/10/27/opinion/elo...
# 31  https://www.vanityfair.com/news/2022/04/elon-m...
# 32  https://www.ted.com/talks/elon_musk_a_future_w...
# 33  https://www.vox.com/recode/2022/10/27/23424938...
# 45   Elon Musk Interview - Elon Musk SpaceX Interview
# 46                          Elon Musk – HarperCollins
# 47  Hiltzik: How does Elon Musk get away with brea...
#
#                  Source_Name
# 0                             Rolling Stone
# 1                                 Wikipedia
# 2                                      CNBC
# 3                    The Hollywood Reporter
# 4                   Encyclopedia Britannica
# 5                          Biography (Bio.)
# 6   Harvard Law School - Harvard University
# 7                   Encyclopedia Britannica
# 8                                   Fortune
# 9                                    Curbed
# 10                                      BBC
# 11                        Wikimedia Commons
# 12                              MarketWatch
# 13                              EOnline.com
# 14                                      NPR
# 15                                     CNBC
# 16                                 POLITICO
# 17                                      CNN
# 18                             Fox Business
# 19                            Inc. Magazine
# 20                         Business Insider
# 21                            New Scientist
# 22                                  Reuters
# 23                                    WIRED
# 24                                 ABC News
# 25                                  YouTube
# 26                                 Fox News
# 27                               People.com
# 28                             Investopedia
# 29                                  Variety
# 30                       The New York Times
# 31                              Vanity Fair
# 32                                      TED
# 33                                      Vox
# 34                                   Forbes
# 35                                 Politico
# 36                                    NBC15
# 37                       The New York Times
# 38                                slate.com
# 39                             The Guardian
# 40                                      WSJ
# 41                                    WIRED
# 42                                 NBC News
# 43                           The New Yorker
# 44                                      PBS
# 45                                  Esquire
# 46                 HarperCollins Publishers
# 47                        Los Angeles Times

# %%
len(all_images)
# Out:
# 48

# %%
dataframe["Images"] = None
for i,image_link in enumerate(all_images):
    imageurl = image_link.find("img",class_="rg_i Q4LuWd").get("src")
    alt_image_url = image_link.find("img",class_="rg_i Q4LuWd").get("data-src")
    try:
        dataframe.iloc[i,-1] = imageurl if imageurl != None else None
        urllib.request.urlretrieve(imageurl,f"{path}/{search_term}_image_{i}.jpg")
    except Exception as e:
        dataframe.iloc[i,-1] = alt_image_url if alt_image_url != None else None
        urllib.request.urlretrieve(alt_image_url,f"{path}/{search_term}image_{i}.jpg")
        pass

# %% [markdown]
# ## total Number of images

# %%
len(os.listdir(path))
# Out:
# 106

# %%
dataframe.head()
# Out:
#                       Blog_Link                       \
# 0  https://www.rollingstone.com/culture/culture-n...
# 1            https://en.wikipedia.org/wiki/Elon_Musk
# 2  https://www.cnbc.com/2023/02/08/biden-billiona...
# 3  https://www.hollywoodreporter.com/business/bus...
# 4     https://www.britannica.com/biography/Elon-Musk
#
#                         Title                              Source_Name         \
# 0  Elon Musk Reportedly Fires Twitter Engineer Ov...            Rolling Stone
# 1                              Elon Musk - Wikipedia                Wikipedia
# 2  Biden billionaire minimum tax: What Elon Musk ...                     CNBC
# 3  Elon Musk, Tesla Beat Investor Suit Over 'Fund...   The Hollywood Reporter
# 4  Elon Musk | Biography, SpaceX, Tesla, Twitter,...  Encyclopedia Britannica
#
#                         Images
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
def path_to_image_html(path):
    return '<img src ="'+ path + '" width="120" >'

# %%
pd.set_option('colheader_justify', 'center')

# %%
dataframe.to_html(f"{search_term}_data.html",escape=False,formatters=dict(Images=path_to_image_html))

# %%
dataframe["Images"][21]
# Out:
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRXK27qC3H2toKeNwIQHDO3IiW35bo-1UX59g&usqp=CAU'

# %% [markdown]
# # Doing it all at once
